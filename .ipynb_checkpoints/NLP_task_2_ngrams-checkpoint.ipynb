# %%
import spacy
from spacy.lang.tr import Turkish
from spacy import displacy
# Out:
# C:\Users\eyimu\anaconda3\envs\tensorflow_env\lib\site-packages\cupy\_environment.py:148: UserWarning: CUDA path could not be detected. Set CUDA_PATH environment variable if CuPy fails to load.
#   'CUDA path could not be detected.'

# %%
# en_core_web_sm CNN ile yapılmış kullanılmaya hazır bir model
nlp = spacy.load('en_core_web_sm')
doc_eng = nlp("My name is Mustafa Ismail Eyi")

# %%
#displacy.render hazır model varsa token'ların birbiriyle olan ilişksini gösteriyor
displacy.render(doc_eng)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="82115d38bd6943d5bd8a77e748711159-0" class="displacy" width="1100" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">My</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">name</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Mustafa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">Ismail</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Eyi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82115d38bd6943d5bd8a77e748711159-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82115d38bd6943d5bd8a77e748711159-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82115d38bd6943d5bd8a77e748711159-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82115d38bd6943d5bd8a77e748711159-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82115d38bd6943d5bd8a77e748711159-0-2" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82115d38bd6943d5bd8a77e748711159-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82115d38bd6943d5bd8a77e748711159-0-3" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82115d38bd6943d5bd8a77e748711159-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,266.5 L762,254.5 778,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82115d38bd6943d5bd8a77e748711159-0-4" stroke-width="2px" d="M420,264.5 C420,2.0 925.0,2.0 925.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82115d38bd6943d5bd8a77e748711159-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,266.5 L933.0,254.5 917.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>

# %%
# Türkçe bir Nlp objesi oluşturup alttaki cümleyi token'larına ayırdık.
nlp = Turkish()
doc = nlp(u"merhabalar, benim adım mustafa ismail eyi.")
for tokens in doc:
    print(tokens)
# Out:
# merhabalar
# ,
# benim
# adım
# mustafa
# ismail
# eyi
# .

# %%
#Üstte belirttiğim gibi türkçe için hazır bir model olmadığı için bunu görselleştiremiyor
displacy.render(doc)
# Out:
# C:\Users\eyimu\anaconda3\envs\nlp\lib\site-packages\spacy\displacy\__init__.py:124: UserWarning: [W005] Doc object not parsed. This means displaCy won't be able to generate a dependency visualization for it. Make sure the Doc was processed with a model that supports dependency parsing, and not just a language class like `English()`. For more info, see the docs:
# https://spacy.io/usage/models
#   warnings.warn(Warnings.W005)
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="tr" id="af069f3e4e3946688d1fe015ae38f93b-0" class="displacy" width="1100" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">merhabalar,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">benim</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">adım</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">mustafa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">ismail</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">eyi.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
# </svg></span>

# %%
# aşağıdaki görüldüğü gibi metnimizi küçük harfli olarak bir nlp objesi oluşturduk
# daha sonrasında her bir token'e, bu token'ların gereksiz kelime olup olmadığına ve noktlama işareti olup olmadığına baktık.
doc = nlp(u"Doğal dil, insanları diğer canlılardan ayıran ve insanların iletişim kurmasını sağlayan en \
temel özelliklerden biridir. Dil, insanın duygu ve düşüncelerini ifade etmede kullandığı ve \
kültürlerin nesiller boyunca aktarılmasını sağlayan bir araçtır. Günlük hayatta karşılaşılan yazılar \
ve sesler birer doğal dil örneğidir. Doğal dilde birçok kelime zamanla yok olurken diğer taraftan \
yeni kelimeler de türetilmektedir. Bu yüzden doğal dil işleme (DDİ) süreci insan için bile karmaşık \
yapıya sahipken, bilgisayar ortamında işlenmesi de zor olmaktadır.  İnsanların dili nasıl kullandığını \
dil bilim alanı incelemektedir. Dil bilimciler ve bilgisayar bilimcilerinin ortak çalışmasını gerektiren \
doğal dil işleme çalışmaları, insan bilgisayar etkileşiminde önemli rol oynamaktadır. Doğal dil \
işleme çalışmaları, yapay zekâ teknolojilerinin, dil bilimi alanında kullanılması ile artmıştır. Yapay \
zekâ çalışma alanlarından olan derin öğrenme yöntemleri ile doğal dile yakın seviyede platformlar \
geliştirilmektedir. Dili anlama, makine çevirisi ve sözcük etiketleme için geliştirilen platformlar \
derin öğrenme yöntemlerinden faydalanmaktadır. Derin öğrenme mimarilerinden olan \
özyinelemeli sinir ağları (Recurrent Neural Network - RNN), metin veya ses verileri gibi sıralı \
verileri işlemede tercih edilmektedir. Bu çalışmada bir RNN türü olan iki yönlü uzun-kısa vadeli \
bellek (Bidirectional Long Short - Term Memory - BLSTM) kullanılarak Türkçe sözcük etiketleme \
modeli önerilmiştir. Önerilen sözcük etiketleme modeli, doğal dil araştırmacılarına, kendi \
analizlerini gerçekleştirme ve kullanabilme imkânı verecek bir platform ile sunulmaktadır. İki yönlü \
LSTM kullanılarak geliştirilen platformun geliştirilme aşamasında uzman görüşü ile geri bildirimler \
alınarak, sözcük etiketleyicinin hata oranı azaltılmıştır.".lower())
for tokens in doc:
    print(tokens,tokens.is_stop, tokens.is_punct)
# Out:
# doğal False False
# dil False False
# , False True
# insanları False False
# diğer True False
# canlılardan False False
# ayıran False False
# ve True False
# insanların False False
# iletişim False False
# kurmasını False False
# sağlayan False False
# en True False
# temel False False
# özelliklerden False False
# biridir False False
# . False True
# dil False False
# , False True
# insanın False False
# duygu False False
# ve True False
# düşüncelerini False False
# ifade False False
# etmede False False
# kullandığı False False
# ve True False
# kültürlerin False False
# nesiller False False
# boyunca False False
# aktarılmasını False False
# sağlayan False False
# bir False False
# araçtır False False
# . False True
# günlük False False
# hayatta False False
# karşılaşılan False False
# yazılar False False
# ve True False
# sesler False False
# birer False False
# doğal False False
# dil False False
# örneğidir False False
# . False True
# doğal False False
# dilde False False
# birçok True False
# kelime False False
# zamanla False False
# yok True False
# olurken False False
# diğer True False
# taraftan False False
# yeni False False
# kelimeler False False
# de True False
# türetilmektedir False False
# . False True
# bu True False
# yüzden False False
# doğal False False
# dil False False
# işleme False False
# ( False True
# ddi̇ False False
# ) False True
# süreci False False
# insan False False
# için True False
# bile True False
# karmaşık False False
# yapıya False False
# sahipken False False
# , False True
# bilgisayar False False
# ortamında False False
# işlenmesi False False
# de True False
# zor False False
# olmaktadır False False
# . False True
#   False False
# i̇nsanların False False
# dili False False
# nasıl True False
# kullandığını False False
# dil False False
# bilim False False
# alanı False False
# incelemektedir False False
# . False True
# dil False False
# bilimciler False False
# ve True False
# bilgisayar False False
# bilimcilerinin False False
# ortak False False
# çalışmasını False False
# gerektiren False False
# doğal False False
# dil False False
# işleme False False
# çalışmaları False False
# , False True
# insan False False
# bilgisayar False False
# etkileşiminde False False
# önemli False False
# rol False False
# oynamaktadır False False
# . False True
# doğal False False
# dil False False
# işleme False False
# çalışmaları False False
# , False True
# yapay False False
# zekâ False False
# teknolojilerinin False False
# , False True
# dil False False
# bilimi False False
# alanında False False
# kullanılması False False
# ile True False
# artmıştır False False
# . False True
# yapay False False
# zekâ False False
# çalışma False False
# alanlarından False False
# olan True False
# derin False False
# öğrenme False False
# yöntemleri False False
# ile True False
# doğal False False
# dile False False
# yakın False False
# seviyede False False
# platformlar False False
# geliştirilmektedir False False
# . False True
# dili False False
# anlama False False
# , False True
# makine False False
# çevirisi False False
# ve True False
# sözcük False False
# etiketleme False False
# için True False
# geliştirilen False False
# platformlar False False
# derin False False
# öğrenme False False
# yöntemlerinden False False
# faydalanmaktadır False False
# . False True
# derin False False
# öğrenme False False
# mimarilerinden False False
# olan True False
# özyinelemeli False False
# sinir False False
# ağları False False
# ( False True
# recurrent False False
# neural False False
# network False False
# - False True
# rnn False False
# ) False True
# , False True
# metin False False
# veya True False
# ses False False
# verileri False False
# gibi True False
# sıralı False False
# verileri False False
# işlemede False False
# tercih False False
# edilmektedir False False
# . False True
# bu True False
# çalışmada False False
# bir False False
# rnn False False
# türü False False
# olan True False
# iki False False
# yönlü False False
# uzun False False
# - False True
# kısa False False
# vadeli False False
# bellek False False
# ( False True
# bidirectional False False
# long False False
# short False False
# - False True
# term False False
# memory False False
# - False True
# blstm False False
# ) False True
# kullanılarak False False
# türkçe False False
# sözcük False False
# etiketleme False False
# modeli False False
# önerilmiştir False False
# . False True
# önerilen False False
# sözcük False False
# etiketleme False False
# modeli False False
# , False True
# doğal False False
# dil False False
# araştırmacılarına False False
# , False True
# kendi True False
# analizlerini False False
# gerçekleştirme False False
# ve True False
# kullanabilme False False
# imkânı False False
# verecek False False
# bir False False
# platform False False
# ile True False
# sunulmaktadır False False
# . False True
# i̇ki False False
# yönlü False False
# lstm False False
# kullanılarak False False
# geliştirilen False False
# platformun False False
# geliştirilme False False
# aşamasında False False
# uzman False False
# görüşü False False
# ile True False
# geri False False
# bildirimler False False
# alınarak False False
# , False True
# sözcük False False
# etiketleyicinin False False
# hata False False
# oranı False False
# azaltılmıştır False False
# . False True

# %%
# %%time
# %%time hücrenin ne kadar zamanda derlendiğini gösterir 

# burada boş liste oluşturduk
# bu token'lardan gereksiz kelime, noktalama işareti ve boşluk(white space) barındıranlardan arındırdık
# sonrasında derlemimiz içerisindeki token'lerın gövdelerini(stem) boş listeye ekledik
# ve bu boş listedeki gövdelere bakış attık.
tokens_of_word = list()
for tokens in (doc):
    if not(tokens.is_stop or tokens.is_punct or tokens.is_space):
        tokens_of_word.append(tokens.lemma_)
print(tokens_of_word)
# Out:
# ['doğal', 'dil', 'insan', 'canlı', 'ayıran', 'insan', 'iletişim', 'kur', 'sağla', 'temel', 'özellik', 'biri', 'dil', 'insan', 'duygu', 'düşünce', 'ifade', 'et', 'kullan', 'kültür', 'nesil', 'boyunca', 'aktar', 'sağla', 'bir', 'araç', 'günlük', 'hayat', 'karşılaş', 'yazı', 'ses', 'birer', 'doğal', 'dil', 'örnek', 'doğal', 'dil', 'kelime', 'zaman', 'ol', 'taraf', 'yeni', 'kelime', 'türe', 'yüz', 'doğal', 'dil', 'işlem', 'ddi̇', 'süreç', 'insan', 'karmaşık', 'yapı', 'sahip', 'bilgisayar', 'ortam', 'işle', 'zor', 'ol', 'i̇nsanların', 'dil', 'kullan', 'dil', 'bilim', 'alan', 'incele', 'dil', 'bilimci', 'bilgisayar', 'bilimci', 'ortak', 'çalış', 'gerek', 'doğal', 'dil', 'işlem', 'çalış', 'insan', 'bilgisayar', 'etkileşim', 'önem', 'rol', 'oyna', 'doğal', 'dil', 'işlem', 'çalış', 'yapay', 'zekâ', 'teknoloji', 'dil', 'bilim', 'alan', 'kullan', 'art', 'yapay', 'zekâ', 'çalış', 'alan', 'derin', 'öğren', 'yöntem', 'doğal', 'dil', 'yakın', 'seviye', 'platform', 'geliş', 'dil', 'anlam', 'makine', 'çeviri', 'sözcük', 'etiketle', 'geliş', 'platform', 'derin', 'öğren', 'yöntem', 'faydalan', 'derin', 'öğren', 'mimari', 'özyinelemeli', 'sinir', 'ağ', 'recurrent', 'neural', 'network', 'rnn', 'metin', 'ses', 'veri', 'sıra', 'veri', 'işle', 'tercih', 'et', 'çalış', 'bir', 'rnn', 'tür', 'iki', 'yön', 'uzun', 'kısa', 'vade', 'bellek', 'bidirectional', 'long', 'short', 'term', 'memory', 'blstm', 'kullan', 'türkçe', 'sözcük', 'etiketle', 'model', 'öner', 'öner', 'sözcük', 'etiketle', 'model', 'doğal', 'dil', 'araştırmacı', 'analiz', 'gerçek', 'kullan', 'imkânı', 'ver', 'bir', 'platform', 'sun', 'i̇ki', 'yön', 'lstm', 'kullan', 'geliş', 'platform', 'geliş', 'aşama', 'uzman', 'görüş', 'geri', 'bildirim', 'alın', 'sözcük', 'etiketleyicinin', 'hata', 'oran', 'azal']
# Wall time: 2 ms

# %%
# spaCy kendi içerisinde bir ngram, bigram veya trigram fonksiyonu içermediği için biz oluşturduk.
def ngram(document, n):
    """document: list, array like object,
    n: n of ngram"""
    ngrams_  = list()
    for i in range(len(document)-n+1):
        ngrams_.append(document[i:i+n])
    return ngrams_

# %%
# 3 sayısı aslında trigram olması gerektiğini belirliyor
ngram(tokens_of_word,3)
# Out:
# [['doğal', 'dil', 'insan'],
#  ['dil', 'insan', 'canlı'],
#  ['insan', 'canlı', 'ayıran'],
#  ['canlı', 'ayıran', 'insan'],
#  ['ayıran', 'insan', 'iletişim'],
#  ['insan', 'iletişim', 'kur'],
#  ['iletişim', 'kur', 'sağla'],
#  ['kur', 'sağla', 'temel'],
#  ['sağla', 'temel', 'özellik'],
#  ['temel', 'özellik', 'biri'],
#  ['özellik', 'biri', 'dil'],
#  ['biri', 'dil', 'insan'],
#  ['dil', 'insan', 'duygu'],
#  ['insan', 'duygu', 'düşünce'],
#  ['duygu', 'düşünce', 'ifade'],
#  ['düşünce', 'ifade', 'et'],
#  ['ifade', 'et', 'kullan'],
#  ['et', 'kullan', 'kültür'],
#  ['kullan', 'kültür', 'nesil'],
#  ['kültür', 'nesil', 'boyunca'],
#  ['nesil', 'boyunca', 'aktar'],
#  ['boyunca', 'aktar', 'sağla'],
#  ['aktar', 'sağla', 'bir'],
#  ['sağla', 'bir', 'araç'],
#  ['bir', 'araç', 'günlük'],
#  ['araç', 'günlük', 'hayat'],
#  ['günlük', 'hayat', 'karşılaş'],
#  ['hayat', 'karşılaş', 'yazı'],
#  ['karşılaş', 'yazı', 'ses'],
#  ['yazı', 'ses', 'birer'],
#  ['ses', 'birer', 'doğal'],
#  ['birer', 'doğal', 'dil'],
#  ['doğal', 'dil', 'örnek'],
#  ['dil', 'örnek', 'doğal'],
#  ['örnek', 'doğal', 'dil'],
#  ['doğal', 'dil', 'kelime'],
#  ['dil', 'kelime', 'zaman'],
#  ['kelime', 'zaman', 'ol'],
#  ['zaman', 'ol', 'taraf'],
#  ['ol', 'taraf', 'yeni'],
#  ['taraf', 'yeni', 'kelime'],
#  ['yeni', 'kelime', 'türe'],
#  ['kelime', 'türe', 'yüz'],
#  ['türe', 'yüz', 'doğal'],
#  ['yüz', 'doğal', 'dil'],
#  ['doğal', 'dil', 'işlem'],
#  ['dil', 'işlem', 'ddi̇'],
#  ['işlem', 'ddi̇', 'süreç'],
#  ['ddi̇', 'süreç', 'insan'],
#  ['süreç', 'insan', 'karmaşık'],
#  ['insan', 'karmaşık', 'yapı'],
#  ['karmaşık', 'yapı', 'sahip'],
#  ['yapı', 'sahip', 'bilgisayar'],
#  ['sahip', 'bilgisayar', 'ortam'],
#  ['bilgisayar', 'ortam', 'işle'],
#  ['ortam', 'işle', 'zor'],
#  ['işle', 'zor', 'ol'],
#  ['zor', 'ol', 'i̇nsanların'],
#  ['ol', 'i̇nsanların', 'dil'],
#  ['i̇nsanların', 'dil', 'kullan'],
#  ['dil', 'kullan', 'dil'],
#  ['kullan', 'dil', 'bilim'],
#  ['dil', 'bilim', 'alan'],
#  ['bilim', 'alan', 'incele'],
#  ['alan', 'incele', 'dil'],
#  ['incele', 'dil', 'bilimci'],
#  ['dil', 'bilimci', 'bilgisayar'],
#  ['bilimci', 'bilgisayar', 'bilimci'],
#  ['bilgisayar', 'bilimci', 'ortak'],
#  ['bilimci', 'ortak', 'çalış'],
#  ['ortak', 'çalış', 'gerek'],
#  ['çalış', 'gerek', 'doğal'],
#  ['gerek', 'doğal', 'dil'],
#  ['doğal', 'dil', 'işlem'],
#  ['dil', 'işlem', 'çalış'],
#  ['işlem', 'çalış', 'insan'],
#  ['çalış', 'insan', 'bilgisayar'],
#  ['insan', 'bilgisayar', 'etkileşim'],
#  ['bilgisayar', 'etkileşim', 'önem'],
#  ['etkileşim', 'önem', 'rol'],
#  ['önem', 'rol', 'oyna'],
#  ['rol', 'oyna', 'doğal'],
#  ['oyna', 'doğal', 'dil'],
#  ['doğal', 'dil', 'işlem'],
#  ['dil', 'işlem', 'çalış'],
#  ['işlem', 'çalış', 'yapay'],
#  ['çalış', 'yapay', 'zekâ'],
#  ['yapay', 'zekâ', 'teknoloji'],
#  ['zekâ', 'teknoloji', 'dil'],
#  ['teknoloji', 'dil', 'bilim'],
#  ['dil', 'bilim', 'alan'],
#  ['bilim', 'alan', 'kullan'],
#  ['alan', 'kullan', 'art'],
#  ['kullan', 'art', 'yapay'],
#  ['art', 'yapay', 'zekâ'],
#  ['yapay', 'zekâ', 'çalış'],
#  ['zekâ', 'çalış', 'alan'],
#  ['çalış', 'alan', 'derin'],
#  ['alan', 'derin', 'öğren'],
#  ['derin', 'öğren', 'yöntem'],
#  ['öğren', 'yöntem', 'doğal'],
#  ['yöntem', 'doğal', 'dil'],
#  ['doğal', 'dil', 'yakın'],
#  ['dil', 'yakın', 'seviye'],
#  ['yakın', 'seviye', 'platform'],
#  ['seviye', 'platform', 'geliş'],
#  ['platform', 'geliş', 'dil'],
#  ['geliş', 'dil', 'anlam'],
#  ['dil', 'anlam', 'makine'],
#  ['anlam', 'makine', 'çeviri'],
#  ['makine', 'çeviri', 'sözcük'],
#  ['çeviri', 'sözcük', 'etiketle'],
#  ['sözcük', 'etiketle', 'geliş'],
#  ['etiketle', 'geliş', 'platform'],
#  ['geliş', 'platform', 'derin'],
#  ['platform', 'derin', 'öğren'],
#  ['derin', 'öğren', 'yöntem'],
#  ['öğren', 'yöntem', 'faydalan'],
#  ['yöntem', 'faydalan', 'derin'],
#  ['faydalan', 'derin', 'öğren'],
#  ['derin', 'öğren', 'mimari'],
#  ['öğren', 'mimari', 'özyinelemeli'],
#  ['mimari', 'özyinelemeli', 'sinir'],
#  ['özyinelemeli', 'sinir', 'ağ'],
#  ['sinir', 'ağ', 'recurrent'],
#  ['ağ', 'recurrent', 'neural'],
#  ['recurrent', 'neural', 'network'],
#  ['neural', 'network', 'rnn'],
#  ['network', 'rnn', 'metin'],
#  ['rnn', 'metin', 'ses'],
#  ['metin', 'ses', 'veri'],
#  ['ses', 'veri', 'sıra'],
#  ['veri', 'sıra', 'veri'],
#  ['sıra', 'veri', 'işle'],
#  ['veri', 'işle', 'tercih'],
#  ['işle', 'tercih', 'et'],
#  ['tercih', 'et', 'çalış'],
#  ['et', 'çalış', 'bir'],
#  ['çalış', 'bir', 'rnn'],
#  ['bir', 'rnn', 'tür'],
#  ['rnn', 'tür', 'iki'],
#  ['tür', 'iki', 'yön'],
#  ['iki', 'yön', 'uzun'],
#  ['yön', 'uzun', 'kısa'],
#  ['uzun', 'kısa', 'vade'],
#  ['kısa', 'vade', 'bellek'],
#  ['vade', 'bellek', 'bidirectional'],
#  ['bellek', 'bidirectional', 'long'],
#  ['bidirectional', 'long', 'short'],
#  ['long', 'short', 'term'],
#  ['short', 'term', 'memory'],
#  ['term', 'memory', 'blstm'],
#  ['memory', 'blstm', 'kullan'],
#  ['blstm', 'kullan', 'türkçe'],
#  ['kullan', 'türkçe', 'sözcük'],
#  ['türkçe', 'sözcük', 'etiketle'],
#  ['sözcük', 'etiketle', 'model'],
#  ['etiketle', 'model', 'öner'],
#  ['model', 'öner', 'öner'],
#  ['öner', 'öner', 'sözcük'],
#  ['öner', 'sözcük', 'etiketle'],
#  ['sözcük', 'etiketle', 'model'],
#  ['etiketle', 'model', 'doğal'],
#  ['model', 'doğal', 'dil'],
#  ['doğal', 'dil', 'araştırmacı'],
#  ['dil', 'araştırmacı', 'analiz'],
#  ['araştırmacı', 'analiz', 'gerçek'],
#  ['analiz', 'gerçek', 'kullan'],
#  ['gerçek', 'kullan', 'imkânı'],
#  ['kullan', 'imkânı', 'ver'],
#  ['imkânı', 'ver', 'bir'],
#  ['ver', 'bir', 'platform'],
#  ['bir', 'platform', 'sun'],
#  ['platform', 'sun', 'i̇ki'],
#  ['sun', 'i̇ki', 'yön'],
#  ['i̇ki', 'yön', 'lstm'],
#  ['yön', 'lstm', 'kullan'],
#  ['lstm', 'kullan', 'geliş'],
#  ['kullan', 'geliş', 'platform'],
#  ['geliş', 'platform', 'geliş'],
#  ['platform', 'geliş', 'aşama'],
#  ['geliş', 'aşama', 'uzman'],
#  ['aşama', 'uzman', 'görüş'],
#  ['uzman', 'görüş', 'geri'],
#  ['görüş', 'geri', 'bildirim'],
#  ['geri', 'bildirim', 'alın'],
#  ['bildirim', 'alın', 'sözcük'],
#  ['alın', 'sözcük', 'etiketleyicinin'],
#  ['sözcük', 'etiketleyicinin', 'hata'],
#  ['etiketleyicinin', 'hata', 'oran'],
#  ['hata', 'oran', 'azal']]

# %%
# burada boş bir liste oluşturduk
# daha sonrasında oluşturduğumuz listeye oluşturulan trigram'larda 2 kereden fazla geçen trigramları listemize o trigram'ı ve sayısını ekledik
listed = list()
listed=((trigram,ngram(tokens_of_word,3).count(trigram)) for trigram in ngram(tokens_of_word,3) if ngram(tokens_of_word,3).count(trigram)>2)

# %%
# oluşturulan bu ikililer yani trigram ve sayısı birden çok kez geçtiği için teke indirgedik
unique = list()
for x in listed:
    if x not in unique:
        unique.append(x)
unique
# Out:
# [(['doğal', 'dil', 'işlem'], 3)]

# %%
# önceki iki hücrede geçen yöntemi bu sefer bigramlar için yaptık
listed = list()
listed=((bigram,ngram(tokens_of_word,2).count(bigram)) for bigram in ngram(tokens_of_word,2) if ngram(tokens_of_word,2).count(bigram)>2)
unique = list()
for x in listed:
    if x not in unique:
        unique.append(x)
unique
# Out:
# [(['doğal', 'dil'], 8),
#  (['dil', 'işlem'], 3),
#  (['derin', 'öğren'], 3),
#  (['sözcük', 'etiketle'], 3)]

# %%
Anahtar Kelimeler— Doğal Dil İşleme, Derin Öğrenme, İki Yönlü Uzun-Kısa Vadeli Bellek,
Özyinelemeli Sinir Ağları, Sözcük Etiketleme
